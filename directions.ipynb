# %% [markdown]
# update current year statcast in terminal
#
# py -3.13 update_statcast_ytd.py
#
# Retrain models
#
# py -3.13 retrain_models.py
#
# Launch Streamlit
#
# py -3.13 -m streamlit run live_dashboard.py
